# %%
import pandas as pd
from pycaret.regression import *

# %%
df_model = pd.read_csv("gold_model.csv")

# %%
df_model["Price"].max()
# Out:
# '2025-03-06 04:00:00+00:00'

# %%
df_model.set_index('Price', inplace=True)

# %%
exp = setup(data=df_model, target='Close', session_id=123)
# Out:
# <style type="text/css">
# #T_83667_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_83667">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83667_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_83667_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83667_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83667_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_83667_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_83667_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_83667_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_83667_row1_col1" class="data row1 col1" >Close</td>
#     </tr>
#     <tr>
#       <th id="T_83667_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
bestmodel=compare_models()
# Out:
# <style type="text/css">
# #T_d7425 th {
#   text-align: left;
# }
# ...

# %%
lightgbm_model = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_cc3fb_row10_col0, #T_cc3fb_row10_col1, #T_cc3fb_row10_col2, #T_cc3fb_row10_col3, #T_cc3fb_row10_col4, #T_cc3fb_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_cc3fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc3fb_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_cc3fb_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_cc3fb_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_cc3fb_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_cc3fb_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_cc3fb_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
par_model = create_model('par')
# Out:
# <style type="text/css">
# #T_730ab_row10_col0, #T_730ab_row10_col1, #T_730ab_row10_col2, #T_730ab_row10_col3, #T_730ab_row10_col4, #T_730ab_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_730ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_730ab_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_730ab_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_730ab_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_730ab_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_730ab_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_730ab_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
plot_model(bestmodel, plot='learning')

# %%
plot_model(lightgbm_model, plot='learning')

# %%
plot_model(par_model, plot='learning')

# %%
save_model(lightgbm_model, 'lightgbm_model_gold_1')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['year', 'month', 'day',
#                                               'dayofweek', 'quarter', 'hour',
#                                               'Close_lag_1week', 'SMA_7',
#                                               'Close_rolling_std_7', 'EMA_5',
#                                               'Close_rolling_max_7',
#                                               'Close_rolling_min_7',
#                                               'Price_Change', 'Gain', 'Loss',
#                                               'Avg_Gain', 'Avg_Loss', 'RS',
#                                               'RSI', 'EMA_1week', 'EMA_2week',
#                                               'MACD', 'Signal', 'Histogram',
#                                               'Volume_Profit'],
# ...

# %%
save_model(par_model, 'par_model_gold_1')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['year', 'month', 'day',
#                                               'dayofweek', 'quarter', 'hour',
#                                               'Close_lag_1week', 'SMA_7',
#                                               'Close_rolling_std_7', 'EMA_5',
#                                               'Close_rolling_max_7',
#                                               'Close_rolling_min_7',
#                                               'Price_Change', 'Gain', 'Loss',
#                                               'Avg_Gain', 'Avg_Loss', 'RS',
#                                               'RSI', 'EMA_1week', 'EMA_2week',
#                                               'MACD', 'Signal', 'Histogram',
#                                               'Volume_Profit'],
# ...

# %%
save_model(bestmodel, 'bestmodel_model_gold_1')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['year', 'month', 'day',
#                                               'dayofweek', 'quarter', 'hour',
#                                               'Close_lag_1week', 'SMA_7',
#                                               'Close_rolling_std_7', 'EMA_5',
#                                               'Close_rolling_max_7',
#                                               'Close_rolling_min_7',
#                                               'Price_Change', 'Gain', 'Loss',
#                                               'Avg_Gain', 'Avg_Loss', 'RS',
#                                               'RSI', 'EMA_1week', 'EMA_2week',
#                                               'MACD', 'Signal', 'Histogram',
#                                               'Volume_Profit'],
# ...

# %%
train_predict = predict_model(lightgbm_model, data=df_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_febe0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_febe0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_febe0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_febe0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_febe0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_febe0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_febe0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_febe0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_febe0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_febe0_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_febe0_row0_col1" class="data row0 col1" >2.3495</td>
# ...

# %%
train_predict = predict_model(bestmodel, data=df_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6853b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6853b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6853b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6853b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6853b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6853b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6853b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6853b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6853b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6853b_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_6853b_row0_col1" class="data row0 col1" >2.5427</td>
# ...

# %%
train_predict = predict_model(par_model, data=df_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a76bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a76bb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a76bb_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a76bb_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a76bb_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a76bb_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a76bb_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a76bb_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a76bb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a76bb_row0_col0" class="data row0 col0" >Passive Aggressive Regressor</td>
#       <td id="T_a76bb_row0_col1" class="data row0 col1" >19.0905</td>
# ...
